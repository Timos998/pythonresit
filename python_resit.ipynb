# %%
import csv
import numpy as np

# %%
#Import csv file
reviews = open('userreviews.csv', newline='', encoding="utf8")
reader = csv.reader(reviews, delimiter=",")
userreviews = list(reader)

# %%
#lists
x = []
y = []
z = []


movie = 'the-emoji-movie'

#Create columns

#list x
for row in userreviews:
    x.append(row[0].split(';')[2]) #list X by author

# %%
#List compute score

#All the scores movie in one list
for j in userreviews:
    if (j[0].split(';')[0]) == movie:
        z.append(int(j[0].split(';')[1])) #list of scores (int is to make words a number)
#print(m)

#Calculate average score
m = sum(z)/len(z) 
print (m)
# Out:
# 2.9662162162162162

# %%
#list y
#list of authors that saw my favorite movie
for i in userreviews:
    if (i[0].split(';')[0]) == movie:
        y.append(i[0].split(';')[2]) #list y by author for fav movie

print(y)
# Out:
# ['EpicLadySponge', 'ryanlikemovies', 'dangers', 'Maxson', 'emojimovie', 'noshigh', 'Eugen_208', 'TJAW', 'JTaoTaoTao', 'jugboy', 'temptershell', 'robertoiglesias', 'chris_nunez73', 'IlluminaTea', 'Startacker', 'stefanowski', 'ZapNorris', 'Rattazustra', 'Yacritic', 'Sktful', 'MrDylanyay', 'Talbis', 'LatinCritic13', 'bomberzx', 'AnHonestCritic', 'pel0s', 'ali2005', 'Michael_Stars_5', 'AdoIf_Hitler', 'KidGamingTime', 'Review123', 'ChocolateMint', 'sgy0003', 'Segaki', 'TM20', 'CorylnTheHouse', 'SergeantSoz', 'dunnyone', 'Striking4gold4', 'mkwiiallpro', 'Zdude2016', 'udecide', 'MrTacoBob', 'EugueneKrabs', 'Emoticonmovie', 'JamieIs', 'LeoYup', 'MrMovieBuff', 'Jadhostgamer072', 'emojimovietrash', 'BananaLuiz', 'BestCoffee', 'stanley834', 'Muskrat147', 'emojimoviesucks', 'keatonmerrell', 'RyanAustin74', 'RadeonMax', 'CineAutoctono', 'vgmkyle', 'MR_headphones', 'JPK', 'legal_rquirmnt', 'Aquameme', 'KarlisKool', 'DylanFarstveet', 'romanyoshioka', 'v0Black_Clouds', 'Thunderfury2575', 'BenK', 'Eliott_Croshaw', 'Teemolandia', 'RendedAsunder', 'bamababe', 'Hattyx', 'CobaltOre', 'Dmochu', 'Hung_Daddy69', 'CriticoDubioso', 'equilibrium', 'uudd40', 'JhonyM', 'Greasyrusianpig', 'Grandmaster2207', 'upsetmoviegoer', 'Arkala', 'Fleent', 'Hdkskdj', 'Wildfire399', 'EmojiMovieLover', 'moviecritic69', 'Frezzy', 'ber06', 'EddDesu', 'Mr-Human-Guy', '1Movieman', 'TheGreatCritic', 'Hamiltonlover12', 'Lucian2', 'anonymous69', 'godmoji', 'SelfishPromo', 'KevinD-Reviews', 'Daniel_Campbell', 'thefishslap', 'TheVietnam', 'Emoji_Movie', 'Nathaniel7300', 'RichardJohnson2', 'Cinemaphile', 'Peeps40836', 'caZCircles', 'Jollyjoe1000', 'Minetrome', 'trashmongrel69', 'GeneMehEmoji', 'Kes4278', 'SSS420i', 'CriticFer', 'PresidentTrump', 'MonkiReviews', 'MrNikitaTV', 'DoritoDoggo77', 'thecriticbanana', 'OhSnapItsCheez', 'FlawlessPug', 'ilovepizza2', 'MLPNASCARFan18', 'adavis248', 'NonProfessional', 'EmojiIsMyCity', 'ridbensdale', 'eagleeyeviking', 'AVdE', 'NerdConsultant', 'Roger1718', 'thedaarkbatty', 'GUMbells', 'RottenDaHam', 'jacoobi456', 'coreyintheh', 'as1an', 'Pippoa', 'Lilahkiz', 'Anarch', 'Aliashhadi', 'RockoDaFoxxo', 'DiamondGuy170']

# %%
#score greator or equal to m
author = str(y)
average = str(m)
moviereviewer = []

for l in userreviews:
    if (l[0].split(';')[1]) >= average:
        if (l[0].split(';')[2]) in author:
            if (l[0].split(';')[0]) is not movie: #to remove the emoji movie film in recommendation list
                moviereviewer.append(l[0].split(';')[0])

moviereviewer = list(dict.fromkeys(moviereviewer))
print(moviereviewer)

#save file
np.savetxt("python_resit_output", moviereviewer,fmt='% s')
# Out:
# ['leap!', 'birth-of-the-dragon', 'jungle', 'valerian-and-the-city-of-a-thousand-planets', 'goon-last-of-the-enforcers', 'the-book-of-henry', 'the-hitmans-bodyguard', 'wish-upon', '47-meters-down', 'annabelle-creation', 'the-house', 'girls-trip', 'war-for-the-planet-of-the-apes', 'pirates-of-the-caribbean-dead-men-tell-no-tales', 'kidnap', 'baby-driver', 'the-limehouse-golem', 'the-little-hours', 'the-dark-tower', 'the-emoji-movie', 'spider-man-homecoming', 'all-eyez-on-me', 'transformers-the-last-knight', 'the-mummy-2017', 'wonder-woman', 'the-big-sick', 'how-to-be-a-latin-lover', 'once-upon-a-time-in-venice', 'diary-of-a-wimpy-kid-the-long-haul', 'kill-switch', 'the-wall-2017', 'everything-everything', 'alien-covenant', 'sleight', 'going-in-style', 'the-circle-2017', 'it-comes-at-night', 'ghost-in-the-shell-2017', 'gifted', 'smurfs-the-lost-village', 'free-fire', 'king-arthur-legend-of-the-sword', 'kong-skull-island', 'their-finest', 'guardians-of-the-galaxy-vol-2', 'snatched', 'the-lego-batman-movie', 'john-wick-chapter-2', 'the-lost-city-of-z', 'chips', 'collide', 'life-2017', 'fist-fight', 'before-i-fall', 'rock-dog', 'logan-2017', 'the-space-between-us', 'the-great-wall', 'a-cure-for-wellness', 'get-out', 'fifty-shades-darker', 'the-girl-with-all-the-gifts', 'the-resurrection-of-gavin-stone', 'rings', 'the-founder', 'split', 'sleepless', 'the-bye-bye-man', 'before-the-flood', 'office-christmas-party', 'patriots-